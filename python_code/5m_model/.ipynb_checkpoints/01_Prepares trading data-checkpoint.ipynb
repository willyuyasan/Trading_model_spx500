# %%
#!pip install yfinance
#!pip install pandas-ta

# %%
import requests
import bs4 as bs
import pickle

import datetime as dt
import os

import pandas as pd
import pandas_datareader.data as pdr
import pandas_ta as ta

import numpy as np

import math

import yfinance as yf

# %%
import sklearn

from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, KBinsDiscretizer
#import category_encoders as ce
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # GET THE TRADING DATA

# %%
#SPX500 data

df_analisys = yf.download('^GSPC',period="15d", interval="5m")
df_analisys = df_analisys.reset_index()

print(df_analisys.shape)
df_analisys
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1123, 7)
#                       Datetime         Open         High          Low  \
# 0    2022-02-11 09:30:00-05:00  4506.270020  4515.200195  4506.209961
# 1    2022-02-11 09:35:00-05:00  4506.930176  4510.259766  4501.529785
# 2    2022-02-11 09:40:00-05:00  4506.770020  4508.549805  4503.470215
# 3    2022-02-11 09:45:00-05:00  4506.799805  4526.330078  4506.799805
# 4    2022-02-11 09:50:00-05:00  4522.209961  4524.580078  4517.299805
# ...                        ...          ...          ...          ...
# 1118 2022-03-04 11:40:00-05:00  4301.069824  4304.160156  4298.279785
# 1119 2022-03-04 11:45:00-05:00  4300.970215  4305.399902  4300.240234
# 1120 2022-03-04 11:50:00-05:00  4304.990234  4305.450195  4299.189941
# 1121 2022-03-04 11:55:00-05:00  4299.959961  4300.859863  4296.509766
# 1122 2022-03-04 12:00:23-05:00  4296.220215  4296.220215  4296.220215
#
#             Close    Adj Close    Volume
# 0     4507.120117  4507.120117         0
# 1     4506.609863  4506.609863  38231078
# 2     4506.879883  4506.879883  36515792
# 3     4522.129883  4522.129883  34592242
# 4     4519.140137  4519.140137  41407225
# ...           ...          ...       ...
# 1118  4300.950195  4300.950195  28614000
# 1119  4304.910156  4304.910156  26138000
# 1120  4299.939941  4299.939941  22634000
# 1121  4297.899902  4297.899902  24867000
# 1122  4296.220215  4296.220215         0
#
# [1123 rows x 7 columns]

# %%
df_analisys.columns
# Out:
# Index(['Datetime', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# SAVING POINT

DIR_OUTPUTS = r'C:\Users\willi\Documents\EJERCICIOS\TRADING\outputs/'

df_analisys.to_pickle(DIR_OUTPUTS + 'df_spx500_5m_raw' + '.pkl')
print(df_analisys.shape)
# Out:
# (1123, 7)

# %%
#df_analisys[ (df_analisys['Datetime']>=dt.datetime(2022,3,3,15,30))]

# %% [markdown]
# # Candles computations

# %%
#Fixes the trading date
df_analisys['Datetime'] = df_analisys['Datetime'].dt.tz_localize(None)
df_analisys['Datetime']
# Out:
# 0      2022-02-11 09:30:00
# 1      2022-02-11 09:35:00
# 2      2022-02-11 09:40:00
# 3      2022-02-11 09:45:00
# 4      2022-02-11 09:50:00
#                ...
# 1118   2022-03-04 11:40:00
# 1119   2022-03-04 11:45:00
# 1120   2022-03-04 11:50:00
# 1121   2022-03-04 11:55:00
# 1122   2022-03-04 12:00:23
# Name: Datetime, Length: 1123, dtype: datetime64[ns]

# %%
df_analisys['date'] = df_analisys['Datetime'].apply(lambda x: x.date())
df_analisys['date']
# 37         1.739746         1.520020
# 38         1.000000         0.409668
# 39         0.060059         0.900391
# 40         0.080078         0.370117
# 41         0.800293         0.079590
# 42         2.209961         1.389648
# 43         1.000000         0.949707
# 44         0.140137         0.469727
# 45         0.270020         4.679688
# 46         0.640137         0.649902
# 47         0.160156         0.000000
# 48         0.000000         2.089844
# 49         0.000000         0.040039

# %%
#Computes candles color
df_analisys['body_disposal']=None
df_analisys.loc[df_analisys['body_size']>0,'body_disposal'] = 1
df_analisys.loc[df_analisys['body_size']<0,'body_disposal'] = 0

print(df_analisys['body_disposal'].value_counts(dropna=False).reset_index().sort_values(['index'],ascending = True))
# Out:
#    index  body_disposal
# 0    0.0            581
# 1    1.0            541
# 2    NaN              1

# %% [markdown]
# # Target signal

# %%
#Computes Target signal

nro_rows = len(df_analisys)
for i in range(0,nro_rows):
    
    profit_threshold = 15
    
    try:
        #Searches for the after indexes where the profit threshold is fullfilled 
        s_threshold = ((df_analisys['Close'][i] - df_analisys['Close'].iloc[i+1:]).abs() > profit_threshold)
        idxs = s_threshold[s_threshold].index
        
        try:
            target_idx = [min(idxs)]
        except:
            target_idx = []
        
        df_data = df_analisys.iloc[target_idx]

        Datetime = df_analisys['Datetime'][i]

        keepcols = ['Datetime','Close']
        df_data = df_data[keepcols]

        dic_rencols = {
            'Datetime':'target_date',
            'Close': 'target_close',
        }

        df_data = df_data.rename(columns=dic_rencols)
        df_data['Datetime'] = Datetime

        if i == 0:
            df_target =df_data.copy()
        else:
            df_target =df_target.append(df_data).copy()
            
    except:
        pass
        
df_target = df_target.reset_index(drop=True)
df_target
# Out:
#              target_date  target_close            Datetime
# 0    2022-02-11 11:35:00   4483.729980 2022-02-11 09:30:00
# 1    2022-02-11 11:35:00   4483.729980 2022-02-11 09:35:00
# 2    2022-02-11 11:35:00   4483.729980 2022-02-11 09:40:00
# 3    2022-02-11 10:10:00   4501.229980 2022-02-11 09:45:00
# 4    2022-02-11 11:05:00   4497.549805 2022-02-11 09:50:00
# ...                  ...           ...                 ...
# 1094 2022-03-04 10:45:00   4293.990234 2022-03-04 09:40:00
# 1095 2022-03-04 09:55:00   4324.250000 2022-03-04 09:45:00
# 1096 2022-03-04 11:10:00   4288.439941 2022-03-04 09:50:00
# 1097 2022-03-04 10:10:00   4296.459961 2022-03-04 09:55:00
# 1098 2022-03-04 10:10:00   4296.459961 2022-03-04 10:00:00
#
# [1099 rows x 3 columns]

# %%
df_analisys_01 = pd.merge(df_analisys,
                         df_target,
                         on = ['Datetime'],
                         how = 'left').copy()

#Computes the target difference in closure prices
df_analisys_01['target_difference'] =  round( df_analisys_01['target_close'] - df_analisys_01['Close'] )

print(df_analisys.shape)
print(df_analisys_01.shape)

print(df_analisys_01['target_difference'].value_counts(dropna=False).reset_index().sort_values(['index'],ascending = True
# 1122         0.000000         0.000000          None                 NaT
#
#       target_close  target_difference  target_date_diff
# 0      4483.729980              -23.0             125.0
# 1      4483.729980              -23.0             120.0
# 2      4483.729980              -23.0             115.0
# 3      4501.229980              -21.0              25.0
# 4      4497.549805              -22.0              75.0
# ...            ...                ...               ...
# 1118           NaN                NaN               NaN
# 1119           NaN                NaN               NaN
# 1120           NaN                NaN               NaN
# 1121           NaN                NaN               NaN
# 1122           NaN                NaN               NaN
#
# [1123 rows x 17 columns]

# %%
df_varbins = df_analisys_01[['target_date_diff']]
df_varbins['target_date_bins'] = pd.qcut(df_varbins['target_date_diff'], 20, duplicates='drop')
df_varbins['target_date_bins'] = df_varbins['target_date_bins'].cat.codes.apply(lambda x: "{:02d}".format(x+1)) + '-' + df_varbins['target_date_bins'].astype(str)

print(df_varbins['target_date_bins'].value_counts(dropna=False).reset_index().sort_values(['index']))
# Out:
#                   index  target_date_bins
# 20               00-nan                24
# 0      01-(4.999, 15.0]                82
# 17      02-(15.0, 20.0]                40
# 15      03-(20.0, 25.0]                48
# 14      04-(25.0, 30.0]                52
# 12      05-(30.0, 37.5]                53
# 2       06-(37.5, 45.0]                75
# 18      07-(45.0, 50.0]                39
# 1       08-(50.0, 60.0]                76
# 19      09-(60.0, 65.0]                39
# 3       10-(65.0, 75.0]                57
# 16      11-(75.0, 85.0]                48
# 8      12-(85.0, 100.0]                54
# 13    13-(100.0, 125.0]                52
# 9     14-(125.0, 173.0]                54
# 7     15-(173.0, 315.0]                55
# 4    16-(315.0, 1095.0]                57
# 10  17-(1095.0, 1145.0]                54
# 6   18-(1145.0, 1265.0]                55
# 11  19-(1265.0, 3995.5]                54
# 5   20-(3995.5, 5475.0]                55
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Computes high time to produce additional categories fo the target

df_varbins = df_varbins.sort_values(['target_date_diff'])
df_varbins = df_varbins[df_varbins.notna().all(axis=1)]
size = round(len(df_varbins)*(0.5))

high_time = df_varbins.iloc[size,:]['target_date_diff']
high_time
# Out:
# 75.0

# %%
mean_time = df_varbins['target_date_diff'].mode()
print('Mean awaiting time to profit: ', mean_time)
# Out:
# Mean awaiting time to profit:  0    35.0
# dtype: float64

# %%
#computes the target order movement
df_analisys_01['target_order'] = 'NULL'

df_analisys_01.loc[df_analisys_01['target_difference'] < 0, 'target_order'] = 'SELL'

df_analisys_01.loc[(df_analisys_01['target_difference'] < 0)
                   &(df_analisys_01['target_date_diff'] > high_time), 'target_order'] = 'SELL2'


df_analisys_01.loc[df_analisys_01['target_difference'] > 0, 'target_order'] = 'BUY'

df_analisys_01.loc[(df_analisys_01['target_difference'] > 0)
                   &(df_analisys_01['target_date_diff'] > high_time), 'target_order'] = 'BUY2'


df_analisys_01.loc[abs(df_analisys_01['target_difference']) < profit_threshold, 'target_order'] = 'NULL'

df_analisys_01['target_order_bin'] = 0
df_analisys_01.loc[df_analisys_01['target_order'] == 'BUY', 'target_order_bin'] = 1

print(df_analisys_01['target_order'].value_counts(dropna=False).reset_index().sort_values(['index'],ascending = True))
print(df_analisys_01['target_order_bin'].value_counts(dropna=False).reset_index().sort_values(['index'],ascending = True))
# Out:
#    index  target_order
# 2    BUY           240
# 3   BUY2           149
# 4   NULL            24
# 1   SELL           321
# 0  SELL2           389
#    index  target_order_bin
# 0      0               883
# 1      1               240

# %% [markdown]
# # MACD and EMA indicators

# %%
# # Calculate MACD values using the pandas_ta library
df_macd = df_analisys_01.ta.macd(close='Close', fast=12, slow=26, signal=9, append=True)
df_macd
# Out:
#       MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9
# 0              NaN            NaN            NaN
# 1              NaN            NaN            NaN
# 2              NaN            NaN            NaN
# 3              NaN            NaN            NaN
# 4              NaN            NaN            NaN
# ...            ...            ...            ...
# 1118     -9.535646       3.252533     -12.788179
# 1119     -8.237070       3.640887     -11.877957
# 1120     -7.522282       3.484540     -11.006822
# 1121     -7.039276       3.174036     -10.213313
# 1122     -6.714626       2.798950      -9.513576
#
# [1123 rows x 3 columns]

# %%
ewm50 = df_analisys_01['Close'].ewm(span=50, adjust=False, min_periods=50).mean()
ewm200 = df_analisys_01['Close'].ewm(span=200, adjust=False, min_periods=200).mean()

df_macd['ewm50'] = ewm50
df_macd['ewm200'] = ewm200

#df_analisys_01['ewm50'] = ewm50
#df_analisys_01['ewm200'] = ewm200

df_analisys_01['diff_ewm50'] = df_analisys_01['Close'] - ewm50
df_analisys_01['diff_ewm200'] = df_analisys_01['Close'] - ewm200

df_analisys_01
# Out:
#                 Datetime         Open         High          Low        Close  \
# 0    2022-02-11 09:30:00  4506.270020  4515.200195  4506.209961  4507.120117
# 1    2022-02-11 09:35:00  4506.930176  4510.259766  4501.529785  4506.609863
# 2    2022-02-11 09:40:00  4506.770020  4508.549805  4503.470215  4506.879883
# 3    2022-02-11 09:45:00  4506.799805  4526.330078  4506.799805  4522.129883
# 4    2022-02-11 09:50:00  4522.209961  4524.580078  4517.299805  4519.140137
# ...                  ...          ...          ...          ...          ...
# 1118 2022-03-04 11:40:00  4301.069824  4304.160156  4298.279785  4300.950195
# 1119 2022-03-04 11:45:00  4300.970215  4305.399902  4300.240234  4304.910156
# 1120 2022-03-04 11:50:00  4304.990234  4305.450195  4299.189941  4299.939941
# 1121 2022-03-04 11:55:00  4299.959961  4300.859863  4296.509766  4297.899902
# 1122 2022-03-04 12:00:23  4296.220215  4296.220215  4296.220215  4296.220215
#
#         Adj Close    Volume        date  body_size  abs_body_size  ...  \
# 0     4507.120117         0  2022-02-11   0.850098       0.850098  ...
# 1     4506.609863  38231078  2022-02-11  -0.320312       0.320312  ...
# 2     4506.879883  36515792  2022-02-11   0.109863       0.109863  ...
# 3     4522.129883  34592242  2022-02-11  15.330078      15.330078  ...
# 4     4519.140137  41407225  2022-02-11  -3.069824       3.069824  ...
# ...           ...       ...         ...        ...            ...  ...
# 1118  4300.950195  28614000  2022-03-04  -0.119629       0.119629  ...
# 1119  4304.910156  26138000  2022-03-04   3.939941       3.939941  ...
# 1120  4299.939941  22634000  2022-03-04  -5.050293       5.050293  ...
# 1121  4297.899902  24867000  2022-03-04  -2.060059       2.060059  ...
# 1122  4296.220215         0  2022-03-04   0.000000       0.000000  ...
#
#       target_close  target_difference target_date_diff target_order  \
# 0      4483.729980              -23.0            125.0        SELL2
# 1      4483.729980              -23.0            120.0        SELL2
# 2      4483.729980              -23.0            115.0        SELL2
# 3      4501.229980              -21.0             25.0         SELL
# 4      4497.549805              -22.0             75.0         SELL
# ...            ...                ...              ...          ...
# 1118           NaN                NaN              NaN         NULL
# 1119           NaN                NaN              NaN         NULL
# 1120           NaN                NaN              NaN         NULL
# 1121           NaN                NaN              NaN         NULL
# 1122           NaN                NaN              NaN         NULL
#
#       target_order_bin  MACD_12_26_9  MACDh_12_26_9 MACDs_12_26_9  diff_ewm50  \
#
# 199    4430.589844              -24.0           1405.0        SELL2
# 200    4430.589844              -24.0           1400.0        SELL2
# 201    4430.589844              -23.0           1395.0        SELL2
# 202    4436.979980              -24.0           1230.0        SELL2
# 203    4436.979980              -27.0           1225.0        SELL2
# ...            ...                ...              ...          ...
# 1118           NaN                NaN              NaN         NULL
# 1119           NaN                NaN              NaN         NULL
# 1120           NaN                NaN              NaN         NULL
# 1121           NaN                NaN              NaN         NULL
# 1122           NaN                NaN              NaN         NULL
#
#       target_order_bin  MACD_12_26_9  MACDh_12_26_9 MACDs_12_26_9  diff_ewm50  \
# 199                  0     -1.025044      -1.301737      0.276693    7.363707
# 200                  0     -0.767477      -0.835336      0.067859    7.180489
# 201                  0     -0.687732      -0.604472     -0.083259    5.323553
# 202                  0     -0.001597       0.065330     -0.066927   12.531778
# 203                  0      0.771334       0.670609      0.100726   14.874837
# ...                ...           ...            ...           ...         ...
# 1118                 0     -9.535646       3.252533    -12.788179  -23.729425
# 1119                 0     -8.237070       3.640887    -11.877957  -18.994191
# 1120                 0     -7.522282       3.484540    -11.006822  -23.024625
# 1121                 0     -7.039276       3.174036    -10.213313  -24.081736
# 1122                 0     -6.714626       2.798950     -9.513576  -24.751172
#
#       diff_ewm200
# 199      9.475278
# 200      9.489767
# 201      7.772008
# 202     15.337588
# 203     18.105815
# ...           ...
# 1118   -49.902857
# 1119   -45.485753
# 1120   -49.953918
# 1121   -51.476605
# 1122   -52.627374
#
# [924 rows x 24 columns]

# %% [markdown]
# # Data preparation

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ## Close price info

# %%
# Prepares previos close info as input variables

for i in range(0,len(df_analisys_02)):
    #i=2
    
    ###############################################################################################
    nro_close_lag = 80

    if i==0:
        X = df_analisys_02.iloc[-(nro_close_lag + i):,][['Close']]
        Datetime = df_analisys_02.iloc[-1:,]['Datetime'].iloc[0]
    else:
        X = df_analisys_02.iloc[-(nro_close_lag + i):-i,][['Close']]
        Datetime = df_analisys_02.iloc[-(i+1):,]['Datetime'].iloc[0]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X_ss = sscaler.fit_transform(X)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss80_close_' + str(x) for x in range(len(X_ss),0,-1) ]
    df_ssdata = pd.DataFrame(X_ss.T,columns=ls_columns)
    ###############################################################################################


    ###############################################################################################
    nro_close_lag2 = 130

    if i==0:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):,][['Close']]
    else:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):-i,][['Close']]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X2_ss = sscaler.fit_transform(X2)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss160_close_' + str(x) for x in range(len(X2_ss),0,-1) ]
    df_ssdata2 = pd.DataFrame(X2_ss.T,columns=ls_columns)

    # Keep anly a few of this standarization
    
    try:
        ls_keepcols = ['ss160_close_' + str(x) for x in range(30,0,-1) ]
        df_ssdata2 = df_ssdata2[ls_keepcols]
    except:
        pass
    ###############################################################################################


    ###############################################################################################
    #Computes slopes before the last close
    ls_linreg_coefs = []
    
    for j in [3,5,8,13]:
        y = X_ss[-j:]
        x = np.array([range(0,j)]).reshape(-1,1)


        linreg = LinearRegression()
        
        try:
            linreg.fit(x,y)
            linreg_coef = linreg.coef_[0][0]

            ls_linreg_coefs.append(linreg_coef)
            
        except:
            pass

    ls_columns = ['slope_close_' + str(x) for x in range(0,len(ls_linreg_coefs)) ]

    df_linregcoefs = pd.DataFrame(np.array([ls_linreg_coefs]),columns=ls_columns)
    df_linregcoefs
    ###############################################################################################

    # Joins the ss closes df with the slopes df
    df_close_info = pd.concat([df_ssdata,df_ssdata2,df_linregcoefs],axis=1,sort=False)
    df_close_info['Datetime'] = Datetime
    
    if i == 0:
        df_close_info_01 = df_close_info.copy()
    else:
        df_close_info_01 = df_close_info_01.append(df_close_info,sort=False).copy()
        
df_close_info_01 = df_close_info_01.reset_index(drop=True)
df_close_info_01
# Out:
#      ss80_close_80  ss80_close_79  ss80_close_78  ss80_close_77  \
# 0         0.560435       0.622429       0.694500       0.715161
# 1         0.486435       0.542791       0.605403       0.678192
# 2         0.418531       0.469132       0.526065       0.589317
# 3         0.503121       0.399368       0.450445       0.507914
# 4         0.290079       0.488439       0.383761       0.435294
# ..             ...            ...            ...            ...
# 919            NaN            NaN            NaN            NaN
# 920            NaN            NaN            NaN            NaN
# 921            NaN            NaN            NaN            NaN
# 922            NaN            NaN            NaN            NaN
# 923            NaN            NaN            NaN            NaN
#
#      ss80_close_76  ss80_close_75  ss80_close_74  ss80_close_73  \
# 0         0.734535       0.575420       0.363594       1.100834
# 1         0.699058       0.718625       0.557925       0.343990
# 2         0.662851       0.683930       0.703697       0.541354
# 3         0.571762       0.645988       0.667266       0.687219
# 4         0.493275       0.557691       0.632579       0.654046
# ..             ...            ...            ...            ...
# 919            NaN            NaN            NaN            NaN
# 920            NaN            NaN            NaN            NaN
# 921            NaN            NaN            NaN            NaN
# 922            NaN            NaN            NaN            NaN
# 923            NaN            NaN            NaN            NaN
#
#      ss80_close_72  ss80_close_71  ...  ss160_close_5  ss160_close_4  \
# 0         0.919746       0.898834  ...      -1.666877      -1.558404
# 1         1.088572       0.905682  ...      -1.701556      -1.703486
# 2         0.325230       1.077428  ...      -1.961813      -1.738191
# 3         0.523347       0.305188  ...      -1.899224      -2.000192
# 4         0.674177       0.508845  ...      -1.953256      -1.934260
# ..             ...            ...  ...            ...            ...
# 919            NaN            NaN  ...      -0.672721      -0.646155
# 920            NaN            NaN  ...            NaN      -0.403259
# 921            NaN            NaN  ...            NaN            NaN
# 922            NaN            NaN  ...            NaN            NaN
# 923            NaN            NaN  ...            NaN            NaN
#
#      ss160_close_3  ss160_close_2  ss160_close_1  slope_close_0  \
# 0        -1.694550      -1.750432      -1.796442      -0.048044
# 1        -1.594039      -1.731408      -1.787791      -0.091445
# 2        -1.740138      -1.629722      -1.768306      -0.013313
# 3        -1.774620      -1.776584      -1.665205       0.051747
# 4        -2.036055      -1.808636      -1.810616       0.106696
# ..             ...            ...            ...            ...
# 919      -1.042638       0.824065       1.537450       1.290044
# 920      -0.366107      -0.920573       1.689939       1.028023
# 921       0.632436       0.779236      -1.411672      -1.022054
# 922            NaN      -1.000000       1.000000            NaN
# 923            NaN            NaN       0.000000            NaN
#
#      slope_close_1  slope_close_2  slope_close_3            Datetime
# 0        -0.042545       0.006960       0.024505 2022-03-04 12:00:23
# 1        -0.018916       0.020583       0.029059 2022-03-04 11:55:00
# 2         0.046834       0.031398       0.026683 2022-03-04 11:50:00
# 3         0.065422       0.049519       0.023767 2022-03-04 11:45:00
# 4         0.038895       0.043416       0.012005 2022-03-04 11:40:00
# ..             ...            ...            ...                 ...
# 919       0.589056            NaN            NaN 2022-02-15 13:25:00
# 920            NaN            NaN            NaN 2022-02-15 13:20:00
# 921            NaN            NaN            NaN 2022-02-15 13:15:00
# 922            NaN            NaN            NaN 2022-02-15 13:10:00
# 923            NaN            NaN            NaN 2022-02-15 13:05:00
#
# [924 rows x 115 columns]

# %%
df_close_info_01[[
    'ss80_close_1',
    'ss80_close_2',
    'ss80_close_3',
    'ss80_close_4',
    
    'ss160_close_1',
    'ss160_close_2',
    'ss160_close_3',
    'ss160_close_4',
]]
# Out:
#      ss80_close_1  ss80_close_2  ss80_close_3  ss80_close_4  ss160_close_1  \
# 0       -1.335097     -1.291707     -1.239010     -1.110620      -1.796442
# 1       -1.327799     -1.274576     -1.144908     -1.248219      -1.787791
# 2       -1.309888     -1.178894     -1.283262     -1.281422      -1.768306
# 3       -1.213103     -1.318455     -1.316597     -1.529962      -1.665205
# 4       -1.349364     -1.347490     -1.562756     -1.466401      -1.810616
# ..            ...           ...           ...           ...            ...
# 919      1.537450      0.824065     -1.042638     -0.646155       1.537450
# 920      1.689939     -0.920573     -0.366107     -0.403259       1.689939
# 921     -1.411672      0.779236      0.632436           NaN      -1.411672
# 922      1.000000     -1.000000           NaN           NaN       1.000000
# 923      0.000000           NaN           NaN           NaN       0.000000
#
#      ss160_close_2  ss160_close_3  ss160_close_4
# 0        -1.750432      -1.694550      -1.558404
# 1        -1.731408      -1.594039      -1.703486
# 2        -1.629722      -1.740138      -1.738191
# 3        -1.776584      -1.774620      -2.000192
# 4        -1.808636      -2.036055      -1.934260
# ..             ...            ...            ...
# 919       0.824065      -1.042638      -0.646155
# 920      -0.920573      -0.366107      -0.403259
# 921       0.779236       0.632436            NaN
# 922      -1.000000            NaN            NaN
# 923            NaN            NaN            NaN
#
# [924 rows x 8 columns]

# %%
data = X
plt.scatter(range(0,len(data)), data)
plt.show()

# %%
data = X2
plt.scatter(range(0,len(data)), data)
plt.show()

# %%
ls_ss160vars = ['ss160_close_' + str(x) for x in range(30,0,-1)]
ls_ss160vars
# Out:
# ['ss160_close_30',
#  'ss160_close_29',
#  'ss160_close_28',
#  'ss160_close_27',
#  'ss160_close_26',
#  'ss160_close_25',
#  'ss160_close_24',
#  'ss160_close_23',
#  'ss160_close_22',
#  'ss160_close_21',
#  'ss160_close_20',
#  'ss160_close_19',
#  'ss160_close_18',
#  'ss160_close_17',
#  'ss160_close_16',
#  'ss160_close_15',
#  'ss160_close_14',
#  'ss160_close_13',
#  'ss160_close_12',
#  'ss160_close_11',
#  'ss160_close_10',
#  'ss160_close_9',
#  'ss160_close_8',
#  'ss160_close_7',
#  'ss160_close_6',
#  'ss160_close_5',
#  'ss160_close_4',
#  'ss160_close_3',
#  'ss160_close_2',
#  'ss160_close_1']

# %%
ls_ss80vars = ['ss80_close_' + str(x) for x in range(80,8,-1) ]
ls_ss80vars
# Out:
# ['ss80_close_80',
#  'ss80_close_79',
#  'ss80_close_78',
#  'ss80_close_77',
#  'ss80_close_76',
#  'ss80_close_75',
#  'ss80_close_74',
#  'ss80_close_73',
#  'ss80_close_72',
#  'ss80_close_71',
#  'ss80_close_70',
#  'ss80_close_69',
#  'ss80_close_68',
#  'ss80_close_67',
#  'ss80_close_66',
#  'ss80_close_65',
#  'ss80_close_64',
#  'ss80_close_63',
#  'ss80_close_62',
#  'ss80_close_61',
#  'ss80_close_60',
#  'ss80_close_59',
#  'ss80_close_58',
#  'ss80_close_57',
#  'ss80_close_56',
#  'ss80_close_55',
#  'ss80_close_54',
#  'ss80_close_53',
#  'ss80_close_52',
#  'ss80_close_51',
#  'ss80_close_50',
#  'ss80_close_49',
#  'ss80_close_48',
#  'ss80_close_47',
#  'ss80_close_46',
#  'ss80_close_45',
#  'ss80_close_44',
#  'ss80_close_43',
#  'ss80_close_42',
#  'ss80_close_41',
#  'ss80_close_40',
#  'ss80_close_39',
#  'ss80_close_38',
#  'ss80_close_37',
#  'ss80_close_36',
#  'ss80_close_35',
#  'ss80_close_34',
#  'ss80_close_33',
#  'ss80_close_32',
#  'ss80_close_31',
#  'ss80_close_30',
#  'ss80_close_29',
#  'ss80_close_28',
#  'ss80_close_27',
#  'ss80_close_26',
#  'ss80_close_25',
#  'ss80_close_24',
#  'ss80_close_23',
#  'ss80_close_22',
#  'ss80_close_21',
#  'ss80_close_20',
#  'ss80_close_19',
#  'ss80_close_18',
#  'ss80_close_17',
#  'ss80_close_16',
#  'ss80_close_15',
#  'ss80_close_14',
#  'ss80_close_13',
#  'ss80_close_12',
#  'ss80_close_11',
#  'ss80_close_10',
#  'ss80_close_9']

# %%
ls_ss80vars2 = ['ss80_close_' + str(x) for x in range(8,0,-1) ]
ls_ss80vars2
# Out:
# ['ss80_close_8',
#  'ss80_close_7',
#  'ss80_close_6',
#  'ss80_close_5',
#  'ss80_close_4',
#  'ss80_close_3',
#  'ss80_close_2',
#  'ss80_close_1']

# %%
ls_slopevars = ['slope_close_' + str(x) for x in range(0,4) ]
ls_slopevars
# Out:
# ['slope_close_0', 'slope_close_1', 'slope_close_2', 'slope_close_3']

# %%
#Assigns correct format to variable to apply transformations
df_close_info_01[ls_ss80vars2] = df_close_info_01[ls_ss80vars2].astype(float)
df_close_info_01[ls_ss80vars] = df_close_info_01[ls_ss80vars].astype(float)
df_close_info_01[ls_ss160vars] = df_close_info_01[ls_ss160vars].astype(float)
df_close_info_01[ls_slopevars] = df_close_info_01[ls_slopevars].astype(float)

# %%
df_close_info_01 = df_close_info_01[df_close_info_01.notna().all(axis=1)]

df_close_info_01[ls_slopevars + ls_ss80vars2 + ls_ss80vars + ls_ss160vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 845 entries, 0 to 844
# Columns: 114 entries, slope_close_0 to ss160_close_1
# dtypes: float64(114)
# memory usage: 759.2 KB

# %%
#Defines X vector to all process

X = df_close_info_01[ls_ss80vars + ls_ss160vars + ls_slopevars + ls_ss80vars2]
print(X.shape)

#y = df_analysis_01[Target_desc]
#y = df_analysis_02[Target_desc + '_coded']
#print(y.shape)
# Out:
# (845, 114)

# %%
# Defines the column trasformer
# This will be the standard schema : start with the pipeline for column transformers and then fit the model

#First a lil pip to treat imputation and scalation in one shot for numerical variables


pca_pip = Pipeline(steps=[('pca',PCA(n_components=3)),])


# Defines the column transformer
rf_transformer = ColumnTransformer([("passthrough", "passthrough", ls_slopevars + ls_ss80vars2),
                                     ("pca1", pca_pip, ls_ss80vars),
                                     ("pca2", pca_pip, ls_ss160vars),
                                        ]) 

#Prepares pip
pip = Pipeline([('preprocessing', rf_transformer),])


#Fits the pipeline to the data
Xtr = rf_transformer.fit_transform(X)

#Saves the total procedure
#pickle.dump(kmeans_proc, open( DIRECTORY + 'kmeans_proc.pkl', 'wb'))

# %%
Xtr.shape
# Out:
# (845, 18)

# %%
#Defines the df of all transformations

ls_ss80pcavars = ['ss80_close_c1','ss80_close_c2','ss80_close_c3']
ls_ss160pcavars = ['ss160_close_c1','ss160_close_c2','ss160_close_c3']

df_close_info_tr_01 = pd.DataFrame(Xtr,columns=ls_slopevars + ls_ss80vars2 + ls_ss80pcavars + ls_ss160pcavars)
print(df_close_info_tr_01.shape)
df_close_info_tr_01
# Out:
# (845, 18)
#      slope_close_0  slope_close_1  slope_close_2  slope_close_3  ss80_close_8  \
# 0        -0.048044      -0.042545       0.006960       0.024505     -1.325549
# 1        -0.091445      -0.018916       0.020583       0.029059     -1.379455
# 2        -0.013313       0.046834       0.031398       0.026683     -1.437974
# 3         0.051747       0.065422       0.049519       0.023767     -1.651279
# %% [markdown]
# ### Histogram

# %%
for c in df_analisys_02.columns.tolist():
    print(c)
# Out:
# Datetime
# Open
# High
# Low
# Close
# Adj Close
# Volume
# date
# body_size
# abs_body_size
# upper_tail_size
# lower_tail_size
# body_disposal
# target_date
# target_close
# target_difference
# target_date_diff
# target_order
# target_order_bin
# MACD_12_26_9
# MACDh_12_26_9
# MACDs_12_26_9
# diff_ewm50
# diff_ewm200

# %%
# Prepares previos MACD H info as input variables

for i in range(0,len(df_analisys_02)):
    #i=2
    
    ###############################################################################################
    nro_close_lag = 80

    if i==0:
        X = df_analisys_02.iloc[-(nro_close_lag + i):,][['MACDh_12_26_9']]
        Datetime = df_analisys_02.iloc[-1:,]['Datetime'].iloc[0]
    else:
        X = df_analisys_02.iloc[-(nro_close_lag + i):-i,][['MACDh_12_26_9']]
        Datetime = df_analisys_02.iloc[-(i+1):,]['Datetime'].iloc[0]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X_ss = sscaler.fit_transform(X)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss80_macdh_' + str(x) for x in range(len(X_ss),0,-1) ]
    df_ssdata = pd.DataFrame(X_ss.T,columns=ls_columns)
    ###############################################################################################


    ###############################################################################################
    nro_close_lag2 = 130

    if i==0:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):,][['MACDh_12_26_9']]
    else:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):-i,][['MACDh_12_26_9']]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X2_ss = sscaler.fit_transform(X2)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss160_macdh_' + str(x) for x in range(len(X2_ss),0,-1) ]
    df_ssdata2 = pd.DataFrame(X2_ss.T,columns=ls_columns)

    # Keep anly a few of this standarization
    
    try:
        ls_keepcols = ['ss160_macdh_' + str(x) for x in range(30,0,-1) ]
        df_ssdata2 = df_ssdata2[ls_keepcols]
    except:
        pass
    ###############################################################################################


    ###############################################################################################
    #Computes slopes before the last close
    ls_linreg_coefs = []
    
    for j in [3,5,8,13]:
        y = X_ss[-j:]
        x = np.array([range(0,j)]).reshape(-1,1)


        linreg = LinearRegression()
        
        try:
            linreg.fit(x,y)
            linreg_coef = linreg.coef_[0][0]

            ls_linreg_coefs.append(linreg_coef)
            
        except:
            pass

    ls_columns = ['slope_macdh_' + str(x) for x in range(0,len(ls_linreg_coefs)) ]

    df_linregcoefs = pd.DataFrame(np.array([ls_linreg_coefs]),columns=ls_columns)
    df_linregcoefs
    ###############################################################################################

    # Joins the ss closes df with the slopes df
    df_macdh_info = pd.concat([df_ssdata,df_ssdata2,df_linregcoefs],axis=1,sort=False)
    df_macdh_info['Datetime'] = Datetime
    
    if i == 0:
        df_macdh_info_01 = df_macdh_info.copy()
    else:
        df_macdh_info_01 = df_macdh_info_01.append(df_macdh_info,sort=False).copy()
        
df_macdh_info_01 = df_macdh_info_01.reset_index(drop=True)
df_macdh_info_01
# Out:
#      ss80_macdh_80  ss80_macdh_79  ss80_macdh_78  ss80_macdh_77  \
# 0         0.816533       0.950381       1.087028       1.162370
# 1         0.696042       0.828500       0.963210       1.100735
# 2         0.586995       0.713577       0.847397       0.983493
# 3         0.494723       0.608835       0.737188       0.872880
# 4         0.179239       0.522431       0.638546       0.769151
# ..             ...            ...            ...            ...
# 919            NaN            NaN            NaN            NaN
# 920            NaN            NaN            NaN            NaN
# 921            NaN            NaN            NaN            NaN
# 922            NaN            NaN            NaN            NaN
# 923            NaN            NaN            NaN            NaN
#
#      ss80_macdh_76  ss80_macdh_75  ss80_macdh_74  ss80_macdh_73  \
# 0         1.191439       1.001589       0.627422       1.143775
# 1         1.176562       1.205819       1.014746       0.638173
# 2         1.122433       1.199040       1.228598       1.035560
# 3         1.010879       1.151762       1.229441       1.259411
# 4         0.907225       1.047645       1.191002       1.270044
# ..             ...            ...            ...            ...
# 919            NaN            NaN            NaN            NaN
# 920            NaN            NaN            NaN            NaN
# 921            NaN            NaN            NaN            NaN
# 922            NaN            NaN            NaN            NaN
# 923            NaN            NaN            NaN            NaN
#
#      ss80_macdh_72  ss80_macdh_71  ...  ss160_macdh_5  ss160_macdh_4  \
# 0         1.232925       1.213625  ...       1.738235       1.917584
# 1         1.157848       1.247571  ...       1.626149       1.767086
# 2         0.655112       1.180133  ...       1.405918       1.659827
# 3         1.063674       0.677905  ...       1.425354       1.442440
# 4         1.300541       1.101367  ...       1.269922       1.466208
# ..             ...            ...  ...            ...            ...
# 919            NaN            NaN  ...      -1.297985      -0.625799
# 920            NaN            NaN  ...            NaN      -1.283840
# 921            NaN            NaN  ...            NaN            NaN
# 922            NaN            NaN  ...            NaN            NaN
# 923            NaN            NaN  ...            NaN            NaN
#
#      ss160_macdh_3  ss160_macdh_2  ss160_macdh_1  slope_macdh_0  \
# 0         1.845380       1.701984       1.528763      -0.144414
# 1         1.948069       1.875208       1.730505      -0.098971
# 2         1.802421       1.985530       1.911813       0.049691
# 3         1.699997       1.844639       2.030378       0.150019
# 4         1.483570       1.745286       1.892264       0.185835
# ..             ...            ...            ...            ...
# 919      -0.293074       0.672259       1.544599       0.918836
# 920      -0.337420       0.131049       1.490211       0.913815
# 921      -1.337453       0.270714       1.066739       1.202096
# 922            NaN      -1.000000       1.000000            NaN
# 923            NaN            NaN       0.000000            NaN
#
#      slope_macdh_1  slope_macdh_2  slope_macdh_3            Datetime
# 0        -0.057885       0.043961       0.107925 2022-03-04 12:00:23
# 1         0.028826       0.090593       0.125605 2022-03-04 11:55:00
# 2         0.121510       0.131091       0.132874 2022-03-04 11:50:00
# 3         0.146417       0.163458       0.134454 2022-03-04 11:45:00
# 4         0.138572       0.167687       0.127555 2022-03-04 11:40:00
# ..             ...            ...            ...                 ...
# 919       0.698323            NaN            NaN 2022-02-15 13:25:00
# 920            NaN            NaN            NaN 2022-02-15 13:20:00
# 921            NaN            NaN            NaN 2022-02-15 13:15:00
# 922            NaN            NaN            NaN 2022-02-15 13:10:00
# 923            NaN            NaN            NaN 2022-02-15 13:05:00
#
# [924 rows x 115 columns]

# %%
# Create variable names lists to naming columns

ls_ss160vars = ['ss160_macdh_' + str(x) for x in range(30,0,-1)]
ls_ss160vars

ls_ss80vars = ['ss80_macdh_' + str(x) for x in range(80,8,-1) ]
ls_ss80vars

ls_ss80vars2 = ['ss80_macdh_' + str(x) for x in range(8,0,-1) ]
ls_ss80vars2

ls_slopevars = ['slope_macdh_' + str(x) for x in range(0,4) ]
ls_slopevars
# Out:
# ['slope_macdh_0', 'slope_macdh_1', 'slope_macdh_2', 'slope_macdh_3']

# %%
#Assigns correct format to variable to apply transformations
df_macdh_info_01[ls_ss80vars2] = df_macdh_info_01[ls_ss80vars2].astype(float)
df_macdh_info_01[ls_ss80vars] = df_macdh_info_01[ls_ss80vars].astype(float)
df_macdh_info_01[ls_ss160vars] = df_macdh_info_01[ls_ss160vars].astype(float)
df_macdh_info_01[ls_slopevars] = df_macdh_info_01[ls_slopevars].astype(float)

# %%
df_macdh_info_01 = df_macdh_info_01[df_macdh_info_01.notna().all(axis=1)]

df_macdh_info_01[ls_slopevars + ls_ss80vars2 + ls_ss80vars + ls_ss160vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 845 entries, 0 to 844
# Columns: 114 entries, slope_macdh_0 to ss160_macdh_1
# dtypes: float64(114)
# memory usage: 759.2 KB

# %%
#Defines X vector to all process

X = df_macdh_info_01[ls_ss80vars + ls_ss160vars + ls_slopevars + ls_ss80vars2]
print(X.shape)

#y = df_analysis_01[Target_desc]
#y = df_analysis_02[Target_desc + '_coded']
#print(y.shape)
# Out:
# (845, 114)

# %%
# Defines the column trasformer
# This will be the standard schema : start with the pipeline for column transformers and then fit the model

#First a lil pip to treat imputation and scalation in one shot for numerical variables


pca_pip = Pipeline(steps=[('pca',PCA(n_components=3)),])


# Defines the column transformer
rf_transformer = ColumnTransformer([("passthrough", "passthrough", ls_slopevars + ls_ss80vars2),
                                     ("pca1", pca_pip, ls_ss80vars),
                                     ("pca2", pca_pip, ls_ss160vars),
                                        ]) 

#Prepares pip
pip = Pipeline([('preprocessing', rf_transformer),])


#Fits the pipeline to the data
Xtr = rf_transformer.fit_transform(X)

#Saves the total procedure
#pickle.dump(kmeans_proc, open( DIRECTORY + 'kmeans_proc.pkl', 'wb'))

# %%
Xtr.shape
# Out:
# (845, 18)

# %%
#Defines the df of all transformations

ls_ss80pcavars = ['ss80_macdh_c1','ss80_macdh_c2','ss80_macdh_c3']
ls_ss160pcavars = ['ss160_macdh_c1','ss160_macdh_c2','ss160_macdh_c3']

df_macdh_info_tr_01 = pd.DataFrame(Xtr,columns=ls_slopevars + ls_ss80vars2 + ls_ss80pcavars + ls_ss160pcavars)
print(df_macdh_info_tr_01.shape)
df_macdh_info_tr_01
# Out:
# (845, 18)
#      slope_macdh_0  slope_macdh_1  slope_macdh_2  slope_macdh_3  ss80_macdh_8  \
# 0        -0.144414      -0.057885       0.043961       0.107925      1.040393
# 1        -0.098971       0.028826       0.090593       0.125605      0.882557
# 2         0.049691       0.121510       0.131091       0.132874      0.681355
# 3         0.150019       0.146417       0.163458       0.134454      0.433031
# 4         0.185835       0.138572       0.167687       0.127555      0.392357
# ..             ...            ...            ...            ...           ...
# 840      -0.009823       0.090267       0.111800       0.095820     -0.131121
# 841       0.132050       0.153532       0.113667       0.058615     -0.193497
# 842       0.169729       0.169792       0.107959       0.013345     -0.385644
# 843       0.166639       0.111040       0.102496      -0.032437     -0.546888
# 844       0.169624       0.065383       0.096936      -0.074905     -0.574372
#
#      ss80_macdh_7  ss80_macdh_6  ss80_macdh_5  ss80_macdh_4  ss80_macdh_3  \
# 0        1.055443      1.282310      1.409716      1.573323      1.507457
# 1        1.053800      1.068947      1.297273      1.425500      1.590159
# 2        0.902010      1.075015      1.090318      1.320993      1.450539
# 3        0.704516      0.928257      1.103681      1.119198      1.353099
# 4        0.459656      0.735906      0.963573      1.142077      1.157866
# ..            ...           ...           ...           ...           ...
# 840     -0.234780     -0.080123      0.107380      0.253391      0.446447
# 841     -0.127708     -0.231473     -0.076658      0.111036      0.257195
# 842     -0.180587     -0.114789     -0.218568     -0.063733      0.123987
# 843     -0.370060     -0.165383     -0.099708     -0.203293     -0.048746
# 844     -0.524563     -0.349115     -0.146037     -0.080874     -0.183651
#
#      ss80_macdh_2  ss80_macdh_1  ss80_macdh_c1  ss80_macdh_c2  ss80_macdh_c3  \
# 0        1.376647      1.218630       3.086982       4.811607      -2.689430
# 1        1.523869      1.392218       2.757394       5.021009      -3.136742
# 2        1.616892      1.549920       2.414150       5.227572      -3.548864
# 3        1.484457      1.653136       2.053440       5.431261      -3.923405
# 4        1.395873      1.529536       1.658634       5.636355      -4.255168
# ..            ...           ...            ...            ...            ...
# 840      0.517222      0.426801       7.199151      -1.012876       1.189741
# 841      0.450448      0.521295       7.224717      -0.129950       1.610683
# 842      0.270166      0.463444       7.087904       0.795292       2.101559
# 843      0.138625      0.284533       6.798520       1.709273       2.591481
# 844     -0.030310      0.155597       6.324108       2.586106       3.068459
#
#      ss160_macdh_c1  ss160_macdh_c2  ss160_macdh_c3
# 0         -6.693451       -1.329995        0.427460
# 1         5.021009      -3.136742       -6.764558       -0.648685
# 2         5.227572      -3.548864       -6.563728        0.070577
# 3         5.431261      -3.923405       -6.287529        0.750187
# 4         5.636355      -4.255168       -5.940440        1.387842
# ..             ...            ...             ...             ...
# 840      -1.012876       1.189741        2.594524       -1.875193
# 841      -0.129950       1.610683        2.680989       -2.212229
# 842       0.795292       2.101559        2.694962       -2.570602
# 843       1.709273       2.591481        2.641130       -2.913116
# 844       2.586106       3.068459        2.449049       -3.229953
#
#      ss160_macdh_c3
# 0          0.427460
# 1          0.297255
# 2         -0.064586
# 3         -0.354958
# 4         -0.583688
# ..              ...
# 840       -2.160777
# 841       -1.744514
# 842       -1.267753
# 843       -0.853144
# 844       -0.472629
#
# [845 rows x 19 columns]

# %% [markdown]
# ### MACD model info

# %%
# Prepares previos MACD model info as input variables

for i in range(0,len(df_analisys_02)):
    #i=2
    
    ###############################################################################################
    nro_close_lag = 80

    if i==0:
        X = df_analisys_02.iloc[-(nro_close_lag + i):,][['MACD_12_26_9']]
        Datetime = df_analisys_02.iloc[-1:,]['Datetime'].iloc[0]
    else:
        X = df_analisys_02.iloc[-(nro_close_lag + i):-i,][['MACD_12_26_9']]
        Datetime = df_analisys_02.iloc[-(i+1):,]['Datetime'].iloc[0]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X_ss = sscaler.fit_transform(X)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss80_macd_' + str(x) for x in range(len(X_ss),0,-1) ]
    df_ssdata = pd.DataFrame(X_ss.T,columns=ls_columns)
    
    try:
        ls_keepcols = ['ss80_macd_' + str(x) for x in range(80,0,-1) ]
        df_ssdata = df_ssdata[ls_keepcols]
    except:
        pass
    ###############################################################################################



    ###############################################################################################
    #Computes slopes before the last close
    ls_linreg_coefs = []
    
    for j in [3,5,8,13]:
        y = X_ss[-j:]
        x = np.array([range(0,j)]).reshape(-1,1)


        linreg = LinearRegression()
        
        try:
            linreg.fit(x,y)
            linreg_coef = linreg.coef_[0][0]

            ls_linreg_coefs.append(linreg_coef)
            
        except:
            pass

    ls_columns = ['slope_macd_' + str(x) for x in range(0,len(ls_linreg_coefs)) ]

    df_linregcoefs = pd.DataFrame(np.array([ls_linreg_coefs]),columns=ls_columns)
    df_linregcoefs
    ###############################################################################################

    # Joins the ss closes df with the slopes df
    df_macd_info = pd.concat([df_ssdata,df_linregcoefs],axis=1,sort=False)
    df_macd_info['Datetime'] = Datetime
    
    if i == 0:
        df_macd_info_01 = df_macd_info.copy()
    else:
        df_macd_info_01 = df_macd_info_01.append(df_macd_info,sort=False).copy()
        
df_macd_info_01 = df_macd_info_01.reset_index(drop=True)
df_macd_info_01
# Out:
#      ss80_macd_80  ss80_macd_79  ss80_macd_78  ss80_macd_77  ss80_macd_76  \
# 0        0.058501      0.168293      0.289309      0.397428      0.493704
# 1       -0.041426      0.057534      0.167335      0.288360      0.396488
# 2       -0.128645     -0.041834      0.057132      0.166939      0.287971
# 3       -0.202085     -0.128916     -0.042100      0.056872      0.166685
# 4       -0.332340     -0.201846     -0.128682     -0.041872      0.057092
# ..            ...           ...           ...           ...           ...
# 919           NaN           NaN           NaN           NaN           NaN
# 920           NaN           NaN           NaN           NaN           NaN
# 921           NaN           NaN           NaN           NaN           NaN
# 922           NaN           NaN           NaN           NaN           NaN
# 923           NaN           NaN           NaN           NaN           NaN
#
#      ss80_macd_75  ss80_macd_74  ss80_macd_73  ss80_macd_72  ss80_macd_71  \
# 0        0.509092      0.440108      0.680730      0.798398      0.881671
# 1        0.492771      0.508160      0.439171      0.679811      0.797489
# 2        0.396106      0.492394      0.507784      0.438791      0.679446
# 3        0.287724      0.395864      0.492158      0.507549      0.438552
# 4        0.166898      0.287928      0.396060      0.492347      0.507737
# ..            ...           ...           ...           ...           ...
# 919           NaN           NaN           NaN           NaN           NaN
# 920           NaN           NaN           NaN           NaN           NaN
# 921           NaN           NaN           NaN           NaN           NaN
# 922           NaN           NaN           NaN           NaN           NaN
# 923           NaN           NaN           NaN           NaN           NaN
#
#      ...  ss80_macd_5  ss80_macd_4  ss80_macd_3  ss80_macd_2  ss80_macd_1  \
# 0    ...    -0.479037    -0.312919    -0.221480    -0.159693    -0.118162
# 1    ...    -0.622762    -0.480045    -0.313914    -0.222469    -0.160677
# 2    ...    -0.786462    -0.623204    -0.480479    -0.314338    -0.222888
# 3    ...    -0.868480    -0.786770    -0.623503    -0.480769    -0.314619
# 4    ...    -0.995856    -0.868192    -0.786488    -0.623233    -0.480510
# ..   ...          ...          ...          ...          ...          ...
# 919  ...    -1.048201    -0.652878    -0.530483     0.522620     1.708942
# 920  ...          NaN    -1.069122    -0.388492    -0.177762     1.635375
# 921  ...          NaN          NaN    -1.377568     0.411783     0.965785
# 922  ...          NaN          NaN          NaN    -1.000000     1.000000
# 923  ...          NaN          NaN          NaN          NaN     0.000000
#
#      slope_macd_0  slope_macd_1  slope_macd_2  slope_macd_3  \
# 0        0.051659      0.087497      0.115868      0.114525
# 1        0.076619      0.118175      0.126525      0.111466
# 2        0.128796      0.143601      0.131515      0.103782
# 3        0.154442      0.141372      0.130728      0.093784
# 4        0.152989      0.127565      0.119075      0.081196
# ..            ...           ...           ...           ...
# 919      1.119712      0.668978           NaN           NaN
# 920      1.011934           NaN           NaN           NaN
# 921      1.171677           NaN           NaN           NaN
# 922           NaN           NaN           NaN           NaN
# 923           NaN           NaN           NaN           NaN
#
#                Datetime
# 0   2022-03-04 12:00:23
# 1   2022-03-04 11:55:00
# 2   2022-03-04 11:50:00
# 3   2022-03-04 11:45:00
# 4   2022-03-04 11:40:00
# ..                  ...
# 919 2022-02-15 13:25:00
# 920 2022-02-15 13:20:00
# 921 2022-02-15 13:15:00
# 922 2022-02-15 13:10:00
# 923 2022-02-15 13:05:00
#
# [924 rows x 85 columns]

# %%
df_macd_info_01 [[
    'ss80_macd_1',
    'ss80_macd_2',
    'ss80_macd_3',
    'ss80_macd_4',
    'ss80_macd_5',
    'ss80_macd_6',
    'ss80_macd_7',
    'ss80_macd_8',
    'ss80_macd_9',
    'ss80_macd_10',
]]
# Out:
#      ss80_macd_1  ss80_macd_2  ss80_macd_3  ss80_macd_4  ss80_macd_5  \
# 0      -0.118162    -0.159693    -0.221480    -0.312919    -0.479037
# 1      -0.160677    -0.222469    -0.313914    -0.480045    -0.622762
# 2      -0.222888    -0.314338    -0.480479    -0.623204    -0.786462
# 3      -0.314619    -0.480769    -0.623503    -0.786770    -0.868480
# 4      -0.480510    -0.623233    -0.786488    -0.868192    -0.995856
# ..           ...          ...          ...          ...          ...
# 919     1.708942     0.522620    -0.530483    -0.652878    -1.048201
# 920     1.635375    -0.177762    -0.388492    -1.069122          NaN
# 921     0.965785     0.411783    -1.377568          NaN          NaN
# 922     1.000000    -1.000000          NaN          NaN          NaN
# 923     0.000000          NaN          NaN          NaN          NaN
#
#      ss80_macd_6  ss80_macd_7  ss80_macd_8  ss80_macd_9  ss80_macd_10
# 0      -0.621743    -0.784978    -0.866673    -0.994321     -1.123283
# 1      -0.786010    -0.867711    -0.995369    -1.124341     -1.250900
# 2      -0.868168    -0.995833    -1.124813    -1.251379     -1.297467
# 3      -0.996153    -1.125139    -1.251713    -1.297803     -1.343806
# 4      -1.124833    -1.251397    -1.297484    -1.343484     -1.365646
# ..           ...          ...          ...          ...           ...
# 919          NaN          NaN          NaN          NaN           NaN
# 920          NaN          NaN          NaN          NaN           NaN
# 921          NaN          NaN          NaN          NaN           NaN
# 922          NaN          NaN          NaN          NaN           NaN
# 923          NaN          NaN          NaN          NaN           NaN
#
# [924 rows x 10 columns]

# %%
# Create variable names lists to naming columns

ls_ss80vars = ['ss80_macd_' + str(x) for x in range(80,8,-1) ]
ls_ss80vars

ls_ss80vars2 = ['ss80_macd_' + str(x) for x in range(8,0,-1) ]
ls_ss80vars2

ls_slopevars = ['slope_macd_' + str(x) for x in range(0,4) ]
ls_slopevars
# Out:
# ['slope_macd_0', 'slope_macd_1', 'slope_macd_2', 'slope_macd_3']

# %%
#Assigns correct format to variable to apply transformations

df_macd_info_01[ls_ss80vars] = df_macd_info_01[ls_ss80vars].astype(float)
df_macd_info_01[ls_ss80vars2] = df_macd_info_01[ls_ss80vars2].astype(float)
df_macd_info_01[ls_slopevars] = df_macd_info_01[ls_slopevars].astype(float)

# %%
df_macd_info_01 = df_macd_info_01[df_macd_info_01.notna().all(axis=1)]

df_macd_info_01[ls_slopevars + ls_ss80vars + ls_ss80vars2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 845 entries, 0 to 844
# Data columns (total 84 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   slope_macd_0  845 non-null    float64
#  1   slope_macd_1  845 non-null    float64
#  2   slope_macd_2  845 non-null    float64
#  3   slope_macd_3  845 non-null    float64
#  4   ss80_macd_80  845 non-null    float64
#  5   ss80_macd_79  845 non-null    float64
#  6   ss80_macd_78  845 non-null    float64
#  7   ss80_macd_77  845 non-null    float64
#  8   ss80_macd_76  845 non-null    float64
#  9   ss80_macd_75  845 non-null    float64
#  10  ss80_macd_74  845 non-null    float64
#  11  ss80_macd_73  845 non-null    float64
#  12  ss80_macd_72  845 non-null    float64
#  13  ss80_macd_71  845 non-null    float64
#  14  ss80_macd_70  845 non-null    float64
#  15  ss80_macd_69  845 non-null    float64
#  16  ss80_macd_68  845 non-null    float64
#  17  ss80_macd_67  845 non-null    float64
#  18  ss80_macd_66  845 non-null    float64
#  19  ss80_macd_65  845 non-null    float64
#  20  ss80_macd_64  845 non-null    float64
#  21  ss80_macd_63  845 non-null    float64
#  22  ss80_macd_62  845 non-null    float64
#  23  ss80_macd_61  845 non-null    float64
#  24  ss80_macd_60  845 non-null    float64
#  25  ss80_macd_59  845 non-null    float64
#  26  ss80_macd_58  845 non-null    float64
#  27  ss80_macd_57  845 non-null    float64
#  28  ss80_macd_56  845 non-null    float64
#  29  ss80_macd_55  845 non-null    float64
#  30  ss80_macd_54  845 non-null    float64
#  31  ss80_macd_53  845 non-null    float64
#  32  ss80_macd_52  845 non-null    float64
#  33  ss80_macd_51  845 non-null    float64
#  34  ss80_macd_50  845 non-null    float64
#  35  ss80_macd_49  845 non-null    float64
#  36  ss80_macd_48  845 non-null    float64
#  37  ss80_macd_47  845 non-null    float64
#  38  ss80_macd_46  845 non-null    float64
#  39  ss80_macd_45  845 non-null    float64
#  40  ss80_macd_44  845 non-null    float64
#  41  ss80_macd_43  845 non-null    float64
#  42  ss80_macd_42  845 non-null    float64
#  43  ss80_macd_41  845 non-null    float64
#  44  ss80_macd_40  845 non-null    float64
#  45  ss80_macd_39  845 non-null    float64
#  46  ss80_macd_38  845 non-null    float64
#  47  ss80_macd_37  845 non-null    float64
#  48  ss80_macd_36  845 non-null    float64
#  49  ss80_macd_35  845 non-null    float64
#  50  ss80_macd_34  845 non-null    float64
#  51  ss80_macd_33  845 non-null    float64
#  52  ss80_macd_32  845 non-null    float64
#  53  ss80_macd_31  845 non-null    float64
#  54  ss80_macd_30  845 non-null    float64
#  55  ss80_macd_29  845 non-null    float64
#  56  ss80_macd_28  845 non-null    float64
#  57  ss80_macd_27  845 non-null    float64
#  58  ss80_macd_26  845 non-null    float64
#  59  ss80_macd_25  845 non-null    float64
#  60  ss80_macd_24  845 non-null    float64
#  61  ss80_macd_23  845 non-null    float64
#  62  ss80_macd_22  845 non-null    float64
#  63  ss80_macd_21  845 non-null    float64
#  64  ss80_macd_20  845 non-null    float64
#  65  ss80_macd_19  845 non-null    float64
#  66  ss80_macd_18  845 non-null    float64
#  67  ss80_macd_17  845 non-null    float64
#  68  ss80_macd_16  845 non-null    float64
#  69  ss80_macd_15  845 non-null    float64
#  70  ss80_macd_14  845 non-null    float64
#  71  ss80_macd_13  845 non-null    float64
#  72  ss80_macd_12  845 non-null    float64
#  73  ss80_macd_11  845 non-null    float64
#  74  ss80_macd_10  845 non-null    float64
#  75  ss80_macd_9   845 non-null    float64
#  76  ss80_macd_8   845 non-null    float64
#  77  ss80_macd_7   845 non-null    float64
#  78  ss80_macd_6   845 non-null    float64
#  79  ss80_macd_5   845 non-null    float64
#  80  ss80_macd_4   845 non-null    float64
#  81  ss80_macd_3   845 non-null    float64
#  82  ss80_macd_2   845 non-null    float64
#  83  ss80_macd_1   845 non-null    float64
# dtypes: float64(84)
# memory usage: 561.1 KB

# %%
#Defines X vector to all process

X = df_macd_info_01[ls_ss80vars + ls_ss80vars2 + ls_slopevars]
print(X.shape)
# Out:
# (845, 84)

# %%
# Defines the column trasformer
# This will be the standard schema : start with the pipeline for column transformers and then fit the model

#First a lil pip to treat imputation and scalation in one shot for numerical variables


pca_pip = Pipeline(steps=[('pca',PCA(n_components=3)),])


# Defines the column transformer
rf_transformer = ColumnTransformer([("passthrough", "passthrough", ls_slopevars + ls_ss80vars2),
                                     ("pca1", pca_pip, ls_ss80vars),
                                        ]) 

#Prepares pip
pip = Pipeline([('preprocessing', rf_transformer),])


#Fits the pipeline to the data
Xtr = rf_transformer.fit_transform(X)

#Saves the total procedure
#pickle.dump(kmeans_proc, open( DIRECTORY + 'kmeans_proc.pkl', 'wb'))

# %%
Xtr.shape
# Out:
# (845, 15)

# %%
#Defines the df of all transformations

ls_ss80pcavars = ['ss80_macd_c1','ss80_macd_c2','ss80_macd_c3']

df_macd_info_tr_01 = pd.DataFrame(Xtr,columns=ls_slopevars + ls_ss80vars2 + ls_ss80pcavars )
print(df_macd_info_tr_01.shape)
df_macd_info_tr_01
# Out:
# (845, 15)
#      slope_macd_0  slope_macd_1  slope_macd_2  slope_macd_3  ss80_macd_8  \
# 0        0.051659      0.087497      0.115868      0.114525    -0.866673
# 1        0.076619      0.118175      0.126525      0.111466    -0.995369
# 2        0.128796      0.143601      0.131515      0.103782    -1.124813
# 3        0.154442      0.141372      0.130728      0.093784    -1.251713
# 4        0.152989      0.127565      0.119075      0.081196    -1.297484
# ..            ...           ...           ...           ...          ...
# 840      0.033221      0.066421      0.055771      0.024818    -0.374836
# 841      0.087309      0.081574      0.045884      0.001817    -0.385509
# 2        0.103782    -1.124813    -0.995833    -0.868168    -0.786462
# 3        0.093784    -1.251713    -1.125139    -0.996153    -0.868480
# 4        0.081196    -1.297484    -1.251397    -1.124833    -0.995856
# ..            ...          ...          ...          ...          ...
# 840      0.024818    -0.374836    -0.443251    -0.400094    -0.326987
# 841      0.001817    -0.385509    -0.380559    -0.448908    -0.405793
# 842     -0.020650    -0.439361    -0.388375    -0.383425    -0.451768
# 843     -0.039089    -0.464084    -0.442771    -0.391780    -0.386830
# 844     -0.052239    -0.424946    -0.467816    -0.446494    -0.395480
#
#      ss80_macd_4  ss80_macd_3  ss80_macd_2  ss80_macd_1  ss80_macd_c1  \
# 0      -0.312919    -0.221480    -0.159693    -0.118162     -7.193386
# 1      -0.480045    -0.313914    -0.222469    -0.160677     -6.899700
# 2      -0.623204    -0.480479    -0.314338    -0.222888     -6.558734
# 3      -0.786770    -0.623503    -0.480769    -0.314619     -6.173960
# 4      -0.868192    -0.786488    -0.623233    -0.480510     -5.747117
# ..           ...          ...          ...          ...           ...
# 840    -0.255754    -0.148715    -0.080968    -0.082273     -6.081800
# 841    -0.332756    -0.261592    -0.154656    -0.086974     -6.202592
# 842    -0.408657    -0.335626    -0.264467    -0.157540     -6.268437
# 843    -0.455179    -0.412064    -0.339027    -0.267863     -6.304159
# 844    -0.390527    -0.458907    -0.415773    -0.342702     -6.308991
#
#      ss80_macd_c2  ss80_macd_c3
# 0       -3.649315      1.056938
# 1       -4.128408      0.913729
# 2       -4.572106      0.777967
# 3       -4.975778      0.649426
# 4       -5.353289      0.528971
# ..            ...           ...
# 840      4.163355      3.114108
# 841      3.626637      3.608228
# 842      3.031060      4.078429
# 843      2.405913      4.471338
# 844      1.741132      4.784735
#
# [845 rows x 16 columns]

# %% [markdown]
# # VOLUME DATA

# %%
# Prepares previos MACD H info as input variables

for i in range(0,len(df_analisys_02)):
    #i=2
    
    ###############################################################################################
    nro_close_lag = 80

    if i==0:
        X = df_analisys_02.iloc[-(nro_close_lag + i):,][['Volume']]
        Datetime = df_analisys_02.iloc[-1:,]['Datetime'].iloc[0]
    else:
        X = df_analisys_02.iloc[-(nro_close_lag + i):-i,][['Volume']]
        Datetime = df_analisys_02.iloc[-(i+1):,]['Datetime'].iloc[0]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X_ss = sscaler.fit_transform(X)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss80_vols_' + str(x) for x in range(len(X_ss),0,-1) ]
    df_ssdata = pd.DataFrame(X_ss.T,columns=ls_columns)
    ###############################################################################################


    ###############################################################################################
    nro_close_lag2 = 130

    if i==0:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):,][['Volume']]
    else:
        X2 = df_analisys_02.iloc[-(nro_close_lag2 + i):-i,][['Volume']]

    # define standard scaler
    sscaler = StandardScaler()

    # transform data
    X2_ss = sscaler.fit_transform(X2)
    #print(X2)

    # Obtains the df of variables of close lags
    ls_columns = ['ss160_vols_' + str(x) for x in range(len(X2_ss),0,-1) ]
    df_ssdata2 = pd.DataFrame(X2_ss.T,columns=ls_columns)

    # Keep anly a few of this standarization
    
    try:
        ls_keepcols = ['ss160_vols_' + str(x) for x in range(30,0,-1) ]
        df_ssdata2 = df_ssdata2[ls_keepcols]
    except:
        pass
    ###############################################################################################


    ###############################################################################################
    #Computes slopes before the last close
    ls_linreg_coefs = []
    
    for j in [3,5,8,13]:
        y = X_ss[-j:]
        x = np.array([range(0,j)]).reshape(-1,1)


        linreg = LinearRegression()
        
        try:
            linreg.fit(x,y)
            linreg_coef = linreg.coef_[0][0]

            ls_linreg_coefs.append(linreg_coef)
            
        except:
            pass

    ls_columns = ['slope_vols_' + str(x) for x in range(0,len(ls_linreg_coefs)) ]

    df_linregcoefs = pd.DataFrame(np.array([ls_linreg_coefs]),columns=ls_columns)
    df_linregcoefs
    ###############################################################################################

    # Joins the ss closes df with the slopes df
    df_vols_info = pd.concat([df_ssdata,df_ssdata2,df_linregcoefs],axis=1,sort=False)
    df_vols_info['Datetime'] = Datetime
    
    if i == 0:
        df_vols_info_01 = df_vols_info.copy()
    else:
        df_vols_info_01 = df_vols_info_01.append(df_vols_info,sort=False).copy()
        
df_vols_info_01 = df_vols_info_01.reset_index(drop=True)
df_vols_info_01
# Out:
#      ss80_vols_80  ss80_vols_79  ss80_vols_78  ss80_vols_77  ss80_vols_76  \
# 920 2022-02-15 13:20:00
# 921 2022-02-15 13:15:00
# 922 2022-02-15 13:10:00
# 923 2022-02-15 13:05:00
#
# [924 rows x 115 columns]

# %%
df_vols_info_01 [[
    'ss80_vols_1',
    'ss80_vols_2',
    'ss80_vols_3',
    'ss80_vols_4',
    'ss80_vols_5',
    'ss80_vols_6',
    'ss80_vols_7',
    'ss80_vols_8',
    'ss80_vols_9',
    'ss80_vols_10',
]]
# Out:
#      ss80_vols_1  ss80_vols_2  ss80_vols_3  ss80_vols_4  ss80_vols_5  \
# 0      -1.647507    -0.255741    -0.380718    -0.184605    -0.046027
# 1      -0.273126    -0.400010    -0.200905    -0.060213     0.162940
# 2      -0.396505    -0.197637    -0.057113     0.165775    -0.059243
# 3      -0.197301    -0.056794     0.166065    -0.058924    -0.098134
# 4      -0.054286     0.168411    -0.056415    -0.095596    -0.217276
# ..           ...          ...          ...          ...          ...
# 919     0.230225     1.786618    -0.509029    -1.177658    -0.330156
# 920     1.660518    -0.406512    -1.008554    -0.245452          NaN
# 921     0.447584    -1.385580     0.937996          NaN          NaN
# 922    -1.000000     1.000000          NaN          NaN          NaN
# 923     0.000000          NaN          NaN          NaN          NaN
#
#      ss80_vols_6  ss80_vols_7  ss80_vols_8  ss80_vols_9  ss80_vols_10
# 0       0.173773    -0.048128    -0.086800    -0.206897      0.262953
# 1      -0.062346    -0.101608    -0.223537     0.253481      0.152463
# 2      -0.098458    -0.220242     0.256208     0.155311      0.265952
# 3      -0.219903     0.256487     0.155603     0.266229      0.342122
# 4       0.258767     0.157956     0.268503     0.344340      0.078609
# ..           ...          ...          ...          ...           ...
# 919          NaN          NaN          NaN          NaN           NaN
# 920          NaN          NaN          NaN          NaN           NaN
# 921          NaN          NaN          NaN          NaN           NaN
# 922          NaN          NaN          NaN          NaN           NaN
# 923          NaN          NaN          NaN          NaN           NaN
#
# [924 rows x 10 columns]

# %%
df_analisys_02.iloc[-8:,]
# Out:
#                 Datetime         Open         High          Low        Close  \
# 1115 2022-03-04 11:25:00  4295.750000  4299.370117  4291.930176  4296.589844
# 1116 2022-03-04 11:30:00  4296.000000  4297.540039  4289.060059  4293.000000
# 1117 2022-03-04 11:35:00  4292.810059  4301.720215  4286.379883  4301.020020
# 1118 2022-03-04 11:40:00  4301.069824  4304.160156  4298.279785  4300.950195
# 1119 2022-03-04 11:45:00  4300.970215  4305.399902  4300.240234  4304.910156
# 1120 2022-03-04 11:50:00  4304.990234  4305.450195  4299.189941  4299.939941
# 1121 2022-03-04 11:55:00  4299.959961  4300.859863  4296.509766  4297.899902
# 1122 2022-03-04 12:00:23  4296.220215  4296.220215  4296.220215  4296.220215
#
#         Adj Close    Volume        date  body_size  abs_body_size  ...  \
# 1115  4296.589844  27885505  2022-03-04   0.839844       0.839844  ...
# 1116  4293.000000  28576461  2022-03-04  -3.000000       3.000000  ...
# 1117  4301.020020  32541214  2022-03-04   8.209961       8.209961  ...
# 1118  4300.950195  28614000  2022-03-04  -0.119629       0.119629  ...
# 1119  4304.910156  26138000  2022-03-04   3.939941       3.939941  ...
# 1120  4299.939941  22634000  2022-03-04  -5.050293       5.050293  ...
# 1121  4297.899902  24867000  2022-03-04  -2.060059       2.060059  ...
# 1122  4296.220215         0  2022-03-04   0.000000       0.000000  ...
#
#       target_close  target_difference target_date_diff target_order  \
# 1115           NaN                NaN              NaN         NULL
# 1116           NaN                NaN              NaN         NULL
# 1117           NaN                NaN              NaN         NULL
# 1118           NaN                NaN              NaN         NULL
# 1119           NaN                NaN              NaN         NULL
# 1120           NaN                NaN              NaN         NULL
# 1121           NaN                NaN              NaN         NULL
# 1122           NaN                NaN              NaN         NULL
#
#       target_order_bin  MACD_12_26_9  MACDh_12_26_9 MACDs_12_26_9  diff_ewm50  \
# 1115                 0    -12.565869       2.375867    -14.941737  -31.437163
# 1116                 0    -11.927247       2.411592    -14.338839  -33.653399
# 1117                 0    -10.651205       2.950107    -13.601312  -24.628149
# 1118                 0     -9.535646       3.252533    -12.788179  -23.729425
# 1119                 0     -8.237070       3.640887    -11.877957  -18.994191
# 1120                 0     -7.522282       3.484540    -11.006822  -23.024625
# 1121                 0     -7.039276       3.174036    -10.213313  -24.081736
# 1122                 0     -6.714626       2.798950     -9.513576  -24.751172
#
#       diff_ewm200
# 1115   -55.862182
# 1116   -58.860464
# 1117   -50.334569
# 1118   -49.902857
# 1119   -45.485753
# 1120   -49.953918
# 1121   -51.476605
# 1122   -52.627374
#
# [8 rows x 24 columns]

# %% [markdown]
# # Attaches target variable to the df with transformations

# %%
ls_tgcols = ['date','Datetime','Close','target_order','target_order_bin','target_close','target_difference','target_date','target_date_diff']


df_transformations_100 = pd.merge(df_close_info_tr_01,
                           df_macdh_info_tr_01,
                           on = ['Datetime'],
                           how='inner'
                         ).copy()

df_transformations_100 = pd.merge(df_transformations_100,
                           df_macd_info_tr_01,
                           on = ['Datetime'],
                           how='inner'
                         ).copy()

df_analisys_100 = pd.merge(df_transformations_100,
                           df_analisys_02[ls_tgcols],
                           on = ['Datetime'],
                           how='inner'
                         ).copy()


df_analisys_100 = df_analisys_100.sort_values(['Datetime']).reset_index(drop=True)

print(df_analisys_100.shape)

print(min(df_analisys_100['Datetime']))
print(max(df_analisys_100['Datetime']))
df_analisys_100
# Out:
# (845, 60)
# 2022-02-16 13:10:00
# 2022-03-04 12:00:23
#                Datetime  slope_close_0  slope_close_1  slope_close_2  \
# 0   2022-02-16 13:10:00       0.177905      -0.003050       0.025702
# 1   2022-02-16 13:15:00       0.053921       0.060510       0.013004
# 2   2022-02-16 13:20:00       0.074142       0.110902       0.023137
# 3   2022-02-16 13:25:00       0.031825       0.048874       0.034117
# 4   2022-02-16 13:30:00      -0.123075      -0.013404       0.035044
# ..                  ...            ...            ...            ...
# 840 2022-03-04 11:40:00       0.106696       0.038895       0.043416
# 841 2022-03-04 11:45:00       0.051747       0.065422       0.049519
# 842 2022-03-04 11:50:00      -0.013313       0.046834       0.031398
# 843 2022-03-04 11:55:00      -0.091445      -0.018916       0.020583
# 844 2022-03-04 12:00:23      -0.048044      -0.042545       0.006960
#
#      slope_close_3  ss80_close_8  ss80_close_7  ss80_close_6  ss80_close_5  \
# 0        -0.039788     -1.426802     -1.226008     -1.088892     -1.013616
# 1        -0.018782     -1.202231     -1.065883     -0.991028     -1.123808
# 2         0.004492     -1.046589     -0.972013     -1.104299     -1.348492
# 3         0.027808     -0.953104     -1.084761     -1.327792     -1.067111
# 4         0.043901     -1.058085     -1.300744     -1.040463     -0.950456
# ..             ...           ...           ...           ...           ...
# 840       0.012005     -1.650527     -1.685153     -1.506925     -1.484383
# 841       0.023767     -1.651279     -1.474624     -1.452280     -1.434458
# 842       0.026683     -1.437974     -1.415840     -1.398183     -1.492797
# 843       0.029059     -1.379455     -1.361977     -1.455633     -1.246398
# 844       0.024505     -1.325549     -1.418281     -1.211109     -1.212913
#
#      ss80_close_4  ...  ss80_macd_c2  ss80_macd_c3        date        Close  \
# 0       -1.147143  ...      1.741132      4.784735  2022-02-16  4439.589844
# 1       -1.368913  ...      2.405913      4.471338  2022-02-16  4439.779785
# 2       -1.086565  ...      3.031060      4.078429  2022-02-16  4441.259766
# 3       -0.976967  ...      3.626637      3.608228  2022-02-16  4440.500000
# 4       -0.933696  ...      4.163355      3.114108  2022-02-16  4438.470215
# ..            ...  ...           ...           ...         ...          ...
# 840     -1.466401  ...     -5.353289      0.528971  2022-03-04  4300.950195
# 841     -1.529962  ...     -4.975778      0.649426  2022-03-04  4304.910156
# 842     -1.281422  ...     -4.572106      0.777967  2022-03-04  4299.939941
# 843     -1.248219  ...     -4.128408      0.913729  2022-03-04  4297.899902
# 844     -1.110620  ...     -3.649315      1.056938  2022-03-04  4296.220215
#
#      target_order  target_order_bin  target_close  target_difference  \
# 0             BUY                 1   4471.140137               32.0
# 1             BUY                 1   4471.140137               31.0
# 2             BUY                 1   4471.140137               30.0
# 3             BUY                 1   4471.140137               31.0
# 4             BUY                 1   4471.140137               33.0
# ..            ...               ...           ...                ...
# 840          NULL                 0           NaN                NaN
# 841          NULL                 0           NaN                NaN
# 842          NULL                 0           NaN                NaN
# 843          NULL                 0           NaN                NaN
# 844          NULL                 0           NaN                NaN
#
#             target_date  target_date_diff
# 0   2022-02-16 14:20:00              70.0
# 1   2022-02-16 14:20:00              65.0
# 2   2022-02-16 14:20:00              60.0
# 3   2022-02-16 14:20:00              55.0
# 4   2022-02-16 14:20:00              50.0
# ..                  ...               ...
# 840                 NaT               NaN
# 841                 NaT               NaN
# 842                 NaT               NaN
# 843                 NaT               NaN
# 844                 NaT               NaN
#
# [845 rows x 60 columns]

# %%
print(df_analisys_100['target_order'].value_counts(dropna=False).reset_index().sort_values(['index'],ascending = True))
# Out:
#    index  target_order
# 2    BUY           218
# 3   BUY2            81
# 4   NULL            24
# 1   SELL           255
# 0  SELL2           267

# %%
# SAVING POINT

DIR_OUTPUTS = r'C:\Users\willi\Documents\EJERCICIOS\TRADING\outputs/'

df_analisys_100.to_pickle(DIR_OUTPUTS + 'df_spx500_5m_s1' + '.pkl')
print(df_analisys_100.shape)
print(dt.datetime.now())
# Out:
# (845, 60)
# 2022-03-04 12:01:09.411295
